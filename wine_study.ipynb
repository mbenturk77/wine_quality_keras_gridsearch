# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
path_red = "C:/Users/Mehmet/Desktop/data/winequality_red.csv"

# %%
red = pd.read_csv(path_red,sep=';')

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
path_white = "C:/Users/Mehmet/Desktop/data/winequality_white.csv"

# %%
white = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", sep=';')

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
na_values = "not available"

# %%
print(white.describe())
print(red.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
print(pd.isnull(red).any())
print(pd.isnull(white).any())
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)

ax[0].hist(red.alcohol, 10, facecolor='red', alpha=0.5, label="Red wine")
ax[1].hist(white.alcohol, 10, facecolor='white', ec="black", lw=0.5, alpha=0.5, label="White wine")

fig.subplots_adjust(left=0, right=1, bottom=0, top=0.5, hspace=0.05, wspace=1)
ax[0].set_ylim([0, 1000])
ax[0].set_xlabel("Alcohol in % Vol")
ax[0].set_ylabel("Frequency")
ax[1].set_xlabel("Alcohol in % Vol")
ax[1].set_ylabel("Frequency")
#ax[0].legend(loc='best')
#ax[1].legend(loc='best')
fig.suptitle("Distribution of Alcohol in % Vol")

plt.show()

# %%
import numpy as np
print(np.histogram(red.alcohol, bins=[7,8,9,10,11,12,13,14,15]))
print(np.histogram(white.alcohol, bins=[7,8,9,10,11,12,13,14,15]))
# Out:
# (array([  0,   7, 673, 452, 305, 133,  21,   8], dtype=int64), array([ 7,  8,  9, 10, 11, 12, 13, 14, 15]))
# (array([   0,  317, 1606, 1256,  906,  675,  131,    7], dtype=int64), array([ 7,  8,  9, 10, 11, 12, 13, 14, 15]))

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(8, 4))

ax[0].scatter(red['quality'], red["sulphates"], color="red")
ax[1].scatter(white['quality'], white['sulphates'], color="white", edgecolors="black", lw=0.5)

ax[0].set_title("Red Wine")
ax[1].set_title("White Wine")
ax[0].set_xlabel("Quality")
ax[1].set_xlabel("Quality")
ax[0].set_ylabel("Sulphates")
ax[1].set_ylabel("Sulphates")
ax[0].set_xlim([0,10])
ax[1].set_xlim([0,10])
ax[0].set_ylim([0,2.5])
ax[1].set_ylim([0,2.5])
fig.subplots_adjust(wspace=0.5)
fig.suptitle("Wine Quality by Amount of Sulphates")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(570)

redlabels = np.unique(red['quality'])
whitelabels = np.unique(white['quality'])

import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
redcolors = np.random.rand(6,4)
whitecolors = np.append(redcolors, np.random.rand(1,4), axis=0)

for i in range(len(redcolors)):
    redy = red['alcohol'][red.quality == redlabels[i]]
    redx = red['volatile acidity'][red.quality == redlabels[i]]
    ax[0].scatter(redx, redy, c=redcolors[i])
for i in range(len(whitecolors)):
    whitey = white['alcohol'][white.quality == whitelabels[i]]
    whitex = white['volatile acidity'][white.quality == whitelabels[i]]
    ax[1].scatter(whitex, whitey, c=whitecolors[i])
    
ax[0].set_title("Red Wine")
ax[1].set_title("White Wine")
ax[0].set_xlim([0,1.7])
ax[1].set_xlim([0,1.7])
ax[0].set_ylim([5,15.5])
ax[1].set_ylim([5,15.5])
ax[0].set_xlabel("Volatile Acidity")
ax[0].set_ylabel("Alcohol")
ax[1].set_xlabel("Volatile Acidity")
ax[1].set_ylabel("Alcohol") 
#ax[0].legend(redlabels, loc='best', bbox_to_anchor=(1.3, 1))
ax[1].legend(whitelabels, loc='best', bbox_to_anchor=(1.3, 1))
#fig.suptitle("Alcohol - Volatile Acidity")
fig.subplots_adjust(top=0.85, wspace=0.7)

plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
# Add `type` column to `red` with value 1
red['type'] = 1

# Add `type` column to `white` with value 0
white['type'] = 0

# Append `white` to `red`
wines = red.append(white, ignore_index=True)

# %%
import seaborn as sns
corr = wines.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  type
# 0      9.4        5     1
# 1      9.8        5     1
# ...

# %%
# Specify the data 
X=wines.iloc[:,0:11]

# Specify the target labels and flatten the array 
y=wines.iloc[:,-1]

# %%
# White wine percentage is 0.7533 that indicates imblance in target values

# %%
y[y==0].count()/len(y)
# Out:
# 0.7538864091118977

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

# %%
# Import `train_test_split` from `sklearn.model_selection`
from sklearn.model_selection import train_test_split
# Split the data up in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X1_train, X1_test, y1_train, y1_test = X_train.copy(), X_test.copy(), y_train.copy(), y_test.copy()

# %%
# Import `StandardScaler` from `sklearn.preprocessing`
from sklearn.preprocessing import StandardScaler

# Define the scaler 
scaler = StandardScaler().fit(X_train)

# Scale the train set
X_train = scaler.transform(X_train)

# Scale the test set
X_test = scaler.transform(X_test)

# %%
# Import batch normalization from keras layers
from keras.layers import BatchNormalization
# Generate a model given an activation and learning rate
def make_model(learning_rate, activation):
  
  # Create an Adam optimizer with the given learning rate
  opt = Adam(lr = learning_rate)
  
  # Create your binary classification model  
  model = Sequential()
  model.add(Dense(128,input_shape=(11,),activation=activation))
  model.add(BatchNormalization())
  model.add(Dense(256, activation = activation))
  model.add(BatchNormalization())
  model.add(Dense(1, activation = 'sigmoid'))

  
  
  # Compile your model with your optimizer, loss, and metrics
  model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])
  return model

# %%
from keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
# Import KerasClassifier from keras scikit learn wrappers
from keras.wrappers.scikit_learn import KerasClassifier

# Create a KerasClassifier
model = KerasClassifier(build_fn =make_model)

# Define the parameters to try out
params = {'activation': ['relu', 'tanh'], 'batch_size': [32, 128, 256], 
          'epochs': [50, 100, 200], 'learning_rate': [0.1, 0.01, 0.001]}

# Create a randomize search cv object passing in the parameters to try

random_search = RandomizedSearchCV(estimator=model, param_distributions = params, cv = KFold(3),verbose=0)

# Running random_search.fit(X,y) 
random_search_fit = random_search.fit(X_train,y_train)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 73ms/step - loss: 0.3507 - accuracy: 0.8862
# Epoch 2/100
# 12/12 [==============================] - 1s 43ms/step - loss: 0.0575 - accuracy: 0.9883
# Epoch 3/100
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0306 - accuracy: 0.9962
# Epoch 4/100
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0213 - accuracy: 0.9959
# Epoch 5/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0177 - accuracy: 0.9972
# Epoch 6/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0161 - accuracy: 0.9972
# Epoch 7/100
# 12/12 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.99 - 0s 32ms/step - loss: 0.0146 - accuracy: 0.9969
# Epoch 8/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0131 - accuracy: 0.9979
# Epoch 9/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0120 - accuracy: 0.9983
# Epoch 10/100
# ...

# %%
best_par = random_search.best_params_
print(best_par)
# Out:
# {'learning_rate': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'tanh'}

# %%
means = random_search.cv_results_['mean_test_score']
stds = random_search.cv_results_['std_test_score']
params = random_search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 0.997013 (0.000324) with: {'learning_rate': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'tanh'}
# 0.969214 (0.022788) with: {'learning_rate': 0.1, 'epochs': 100, 'batch_size': 32, 'activation': 'tanh'}
# 0.995175 (0.001125) with: {'learning_rate': 0.001, 'epochs': 50, 'batch_size': 32, 'activation': 'relu'}
# 0.991268 (0.000326) with: {'learning_rate': 0.1, 'epochs': 200, 'batch_size': 256, 'activation': 'tanh'}
# 0.994486 (0.002028) with: {'learning_rate': 0.1, 'epochs': 100, 'batch_size': 256, 'activation': 'tanh'}
# 0.995864 (0.000564) with: {'learning_rate': 0.1, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'}
# 0.994026 (0.001301) with: {'learning_rate': 0.1, 'epochs': 50, 'batch_size': 128, 'activation': 'tanh'}
# 0.996094 (0.000859) with: {'learning_rate': 0.001, 'epochs': 50, 'batch_size': 256, 'activation': 'relu'}
# 0.996323 (0.000650) with: {'learning_rate': 0.01, 'epochs': 50, 'batch_size': 256, 'activation': 'tanh'}
# ...

# %%
# Create an Adam optimizer with the given learning rate
opt = Adam(lr = best_par['learning_rate'])
  
# Create your binary classification model  
model_tuned = Sequential()
model_tuned.add(Dense(128,input_shape=(11,),activation=best_par['activation']))
model_tuned.add(BatchNormalization())
model_tuned.add(Dense(256, activation =best_par['activation']))
model_tuned.add(BatchNormalization())
model_tuned.add(Dense(1, activation = 'sigmoid'))

  
  
# Compile your model with your optimizer, loss, and metrics
model_tuned.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Model output shape
model_tuned.output_shape
# Out:
# (None, 1)

# %%
# Model summary
model_tuned.summary()
# Out:
# Model: "sequential_2359"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7231 (Dense)           (None, 128)               1536
# _________________________________________________________________
# batch_normalization_7154 (Ba (None, 128)               512
# _________________________________________________________________
# dense_7232 (Dense)           (None, 256)               33024
# _________________________________________________________________
# batch_normalization_7155 (Ba (None, 256)               1024
# _________________________________________________________________
# dense_7233 (Dense)           (None, 1)                 257
# ...
# Total params: 36,353
# Trainable params: 35,585
# Non-trainable params: 768
# _________________________________________________________________

# %%
# Model config
model_tuned.get_config()
# Out:
# {'name': 'sequential_2359',
#  'layers': [{'class_name': 'Dense',
#    'config': {'name': 'dense_7231',
#     'trainable': True,
#     'batch_input_shape': (None, 11),
#     'dtype': 'float32',
#     'units': 128,
#     'activation': 'tanh',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'BatchNormalization',
#    'config': {'name': 'batch_normalization_7154',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': ListWrapper([1]),
#     'momentum': 0.99,
#     'epsilon': 0.001,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
# ...

# %%
# List all weight tensors 
model_tuned.get_weights()
# Out:
# [array([[-0.00645095,  0.27908123, -0.3206404 , ..., -0.45413902,
#          -0.48137715, -0.26564416],
#         [-0.05001776, -0.2060027 , -0.2305576 , ...,  0.67937976,
#          -0.14592868, -0.98089796],
#         [ 0.37397364, -0.09935358, -0.18616496, ..., -0.60183424,
#          -1.2900659 ,  0.4293068 ],
#         ...,
#         [ 0.52733296,  0.05130467, -0.02333586, ..., -0.6046096 ,
#          -0.42830908, -0.5787027 ],
#         [ 0.02143377, -0.12278593,  0.17721702, ...,  0.14904052,
#          -0.42677212,  0.38863724],
#         [ 0.03126403, -0.05008757,  0.7049041 , ...,  0.31751874,
#           0.2966414 ,  0.26841167]], dtype=float32),
#  array([ 1.3407885 ,  0.5556133 ,  1.0275    , -0.47593316, -0.41163927,
#          1.0860031 , -1.7511055 , -0.6282788 , -0.11000892,  0.06555627,
#          0.11678189,  0.83420724,  0.1498638 ,  0.1325981 , -0.9937629 ,
#          2.0998993 , -0.9005978 , -0.03657783, -0.818849  , -0.7236864 ,
# ...

# %%
model_tuned.fit(X_train, y_train,epochs=best_par['epochs'], batch_size=best_par['batch_size'], verbose=1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 2/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0028 - accuracy: 0.9995
# Epoch 3/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0025 - accuracy: 0.9993ETA: 0s - loss: 0.0017 - accuracy: 0.9994 - ETA: 0s - loss: 0.0016 - accuracy: 0.99
# Epoch 4/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0015 - accuracy: 0.9993
# Epoch 5/100
# 17/17 [==============================] - 1s 34ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 6/100
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0031 - accuracy: 0.9986
# Epoch 7/100
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0098 - accuracy: 0.9979
# Epoch 8/100
# 17/17 [==============================] - 1s 30ms/step - loss: 0.0076 - accuracy: 0.9984
# Epoch 9/100
# ...

# %%
y_pred = model_tuned.predict_classes(X_test)

# %%
score = model_tuned.evaluate(X_test, y_test,verbose=1)

print(score)
# Out:
# 68/68 [==============================] - 1s 15ms/step - loss: 0.0431 - accuracy: 0.9949
# [0.04306863248348236, 0.9948717951774597]

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score

# Confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1585,    3],
#        [   8,  549]], dtype=int64)

# %%
# Precision 
precision_score(y_test, y_pred)
# Out:
# 0.9945652173913043

# %%
# Recall
recall_score(y_test, y_pred)
# Out:
# 0.9856373429084381

# %%
# F1 score
f1_score(y_test,y_pred)
# Out:
# 0.9900811541929666

# %%
# Cohen's kappa
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.9866232169249897

# %%
hist_rand_search = model_tuned.fit(X_train, y_train,epochs=best_par['epochs'], batch_size=best_par['batch_size'], verbose=1,validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.0501 - val_accuracy: 0.9958
# Epoch 2/100
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0473 - val_accuracy: 0.9953
# Epoch 3/100
# 17/17 [==============================] - 1s 41ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.0473 - val_accuracy: 0.9958
# Epoch 4/100
# 17/17 [==============================] - 1s 40ms/step - loss: 0.0011 - accuracy: 0.9993 - val_loss: 0.0500 - val_accuracy: 0.9953
# Epoch 5/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.0505 - val_accuracy: 0.9953
# Epoch 6/100
# 17/17 [==============================] - 1s 39ms/step - loss: 7.5720e-04 - accuracy: 0.9995 - val_loss: 0.0528 - val_accuracy: 0.9958
# Epoch 7/100
# ...

# %%
# summarize history for accuracy
plt.plot(hist_rand_search.history['accuracy'])
plt.plot(hist_rand_search.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist_rand_search.history['loss'])
plt.plot(hist_rand_search.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.regularizers import l2
def make_keras_model1(learning_rate=0.01,activation='relu',layer1_units=64, layer2_units=64,dropout_rate=0.1, nbr_features=11,l2_regularization=0):
     
        opt = Adam(lr =learning_rate)        
        model = Sequential()
        model.add(Dense(layer1_units,input_shape=(nbr_features,),activation=activation))
        model.add(BatchNormalization())
        model.add(Dense(layer2_units, activation = activation,kernel_regularizer=l2(l2_regularization)))
        model.add(BatchNormalization())
        model.add(Dropout(rate=dropout_rate))
        model.add(BatchNormalization())
        model.add(Dense(1, activation = 'sigmoid'))
    
        # Compile your model with your optimizer, loss, and metrics
        model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])
        return model

# %%
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasClassifier

keras_estimator = KerasClassifier(make_keras_model1,
                                 learning_rate=0.01,
                                
                                 activation='relu',
                                 batch_size=32, 
                                 layer1_units=64,
                                 layer2_units=32,
                                 l2_regularization=0,
                                 dropout_rate=0,
                                 epochs=10, 
                                 verbose=False)

# %%
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

pipeline_keras = Pipeline([('imputer', SimpleImputer()), 
                           ('scaler', StandardScaler()), 
                           ('model', keras_estimator)])

# %% [raw]
# param_grid_keras ={
#     'imputer__strategy': ['mean', 'median'],
#     'scaler': [MinMaxScaler(), StandardScaler()],
#     'model__layer1_units': [64,128],
#     'model__layer2_units': [32, 64],
#     'model__dropout_rate': [0, 0.2, 0.5],
#     'model__epochs': [10,20,30,40, 60],
#     'model__learning_rate':[0.01,0.1],
#
#     'model__activation':['relu','sigmoid','softmax','tanh'],
#     'model__batch_size':[32,64],
#
# }

# %%
param_grid_keras ={
    
    'scaler': [StandardScaler()],
    'model__layer1_units': [32,64],
    'model__layer2_units': [16, 32],
    'model__dropout_rate': [0, 0.2],
    'model__epochs': [10,20,30],
    'model__learning_rate':[0.01,0.1],
    
    'model__activation':['relu','softmax','tanh'],
    'model__batch_size':[32,64],
    
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error

gridsearch_keras = GridSearchCV(pipeline_keras,
                                param_grid=param_grid_keras,
                                scoring='neg_mean_squared_error',
                                cv=2, 
                                refit=True,
                                verbose=True)

# %%
gridsearch_keras.fit(X1_train, y1_train)
# Out:
# Fitting 2 folds for each of 288 candidates, totalling 576 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 576 out of 576 | elapsed: 82.3min finished
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('imputer', SimpleImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('model',
#                                         <tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x00000027A8E432C8>)]),
#              param_grid={'model__activation': ['relu', 'softmax', 'tanh'],
#                          'model__batch_size': [32, 64],
#                          'model__dropout_rate': [0, 0.2],
#                          'model__epochs': [10, 20, 30],
#                          'model__layer1_units': [32, 64],
#                          'model__layer2_units': [16, 32],
# ...

# %%
print(f'Best params: {gridsearch_keras.best_params_}')
# Out:
# Best params: {'model__activation': 'tanh', 'model__batch_size': 64, 'model__dropout_rate': 0, 'model__epochs': 10, 'model__layer1_units': 32, 'model__layer2_units': 32, 'model__learning_rate': 0.01, 'scaler': StandardScaler()}

# %%
print(f'Best score: {gridsearch_keras.best_score_}')
# Out:
# Best score: -0.002297794117647059

# %%
y_pred_keras = gridsearch_keras.predict(X1_test)

# %%
print(f'Test MSE: {mean_squared_error(y_true=y1_test, y_pred=y_pred_keras)}')
# Out:
# Test MSE: 0.004662004662004662

# %%
print(f'Test MAE: {mean_absolute_error(y_true=y1_test, y_pred=y_pred_keras)}')
# Out:
# Test MAE: 0.004662004662004662

# %%
means = gridsearch_keras.cv_results_['mean_test_score']
stds = gridsearch_keras.cv_results_['std_test_score']
params = gridsearch_keras.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.004136 (0.001838) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0, 'model__epochs': 10, 'model__layer1_units': 32, 'model__layer2_units': 16, 'model__learning_rate': 0.01, 'scaler': StandardScaler()}
# -0.003676 (0.001379) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0, 'model__epochs': 10, 'model__layer1_units': 32, 'model__layer2_units': 16, 'model__learning_rate': 0.1, 'scaler': StandardScaler()}
# -0.003676 (0.000000) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0, 'model__epochs': 10, 'model__layer1_units': 32, 'model__layer2_units': 32, 'model__learning_rate': 0.01, 'scaler': StandardScaler()}
# -0.008502 (0.002987) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0, 'model__epochs': 10, 'model__layer1_units': 32, 'model__layer2_units': 32, 'model__learning_rate': 0.1, 'scaler': StandardScaler()}
# ...

# %%
nbr_features=11    
opt = Adam(lr =gridsearch_keras.best_params_['model__learning_rate'])        
model_keras_grid_searched = Sequential()
model_keras_grid_searched.add(Dense(gridsearch_keras.best_params_['model__layer1_units'],input_shape=(nbr_features,),activation=gridsearch_keras.best_params_['model__activation']))
model_keras_grid_searched.add(BatchNormalization())
model_keras_grid_searched.add(Dense(gridsearch_keras.best_params_['model__layer2_units'], activation = gridsearch_keras.best_params_['model__activation'],kernel_regularizer=l2(0)))
model_keras_grid_searched.add(BatchNormalization())
model_keras_grid_searched.add(Dropout(rate=gridsearch_keras.best_params_['model__dropout_rate']))
model_keras_grid_searched.add(BatchNormalization())
model_keras_grid_searched.add(Dense(gridsearch_keras.best_params_['model__layer2_units'], activation = gridsearch_keras.best_params_['model__activation'],kernel_regularizer=l2(0)))
model_keras_grid_searched.add(Dense(1, activation = 'sigmoid'))
    
# Compile your model with your optimizer, loss, and metrics
model_keras_grid_searched.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])
model_keras_grid_searched.fit(X_train, y_train, epochs = gridsearch_keras.best_params_['model__epochs'],batch_size=gridsearch_keras.best_params_['model__batch_size'])
# Out:
# Epoch 1/10
# 68/68 [==============================] - 1s 12ms/step - loss: 0.0790 - accuracy: 0.9706 0s - loss: 0.1236 -
# Epoch 2/10
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0290 - accuracy: 0.9938
# Epoch 3/10
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0237 - accuracy: 0.9940
# Epoch 4/10
# 68/68 [==============================] - 1s 7ms/step - loss: 0.0203 - accuracy: 0.9954
# Epoch 5/10
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 0.9952
# Epoch 6/10
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9968
# Epoch 7/10
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9943
# Epoch 8/10
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9949
# Epoch 9/10
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9956
# Epoch 10/10
# ...

# %%
h_callback2 = model_keras_grid_searched.fit(X1_train, y1_train, epochs = gridsearch_keras.best_params_['model__epochs'],batch_size=gridsearch_keras.best_params_['model__batch_size'],
               validation_data=(X1_test, y1_test))
# Out:
# Epoch 1/10
# 68/68 [==============================] - 2s 26ms/step - loss: 0.3205 - accuracy: 0.9060 - val_loss: 0.3487 - val_accuracy: 0.8965
# Epoch 2/10
# 68/68 [==============================] - 1s 17ms/step - loss: 0.2365 - accuracy: 0.9324 - val_loss: 0.3769 - val_accuracy: 0.7450
# Epoch 3/10
# 68/68 [==============================] - 1s 14ms/step - loss: 0.2231 - accuracy: 0.9382 - val_loss: 0.2747 - val_accuracy: 0.9259
# Epoch 4/10
# 68/68 [==============================] - 1s 17ms/step - loss: 0.2121 - accuracy: 0.9435 - val_loss: 0.3229 - val_accuracy: 0.9329
# Epoch 5/10
# 68/68 [==============================] - 1s 18ms/step - loss: 0.2100 - accuracy: 0.9421 - val_loss: 0.2890 - val_accuracy: 0.9282
# Epoch 6/10
# 68/68 [==============================] - 1s 16ms/step - loss: 0.2034 - accuracy: 0.9455 - val_loss: 0.4115 - val_accuracy: 0.9035
# Epoch 7/10
# ...

# %%
# summarize history for accuracy
plt.plot(h_callback2.history['accuracy'])
plt.plot(h_callback2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(h_callback2.history['loss'])
plt.plot(h_callback2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model_keras_grid_searched.predict_classes(X_test)

# %%
score = model_keras_grid_searched.evaluate(X_test, y_test,verbose=1)

print(score)
# Out:
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9939
# [0.025666793808341026, 0.9939393997192383]

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1584,    4],
#        [   9,  548]], dtype=int64)

# %%
# Precision 
precision_score(y_test, y_pred)
# Out:
# 0.9927536231884058

# %%
# Recall
recall_score(y_test, y_pred)
# Out:
# 0.9838420107719928

# %%
# F1 score
f1_score(y_test,y_pred)
# Out:
# 0.9882777276825969

# %%
# Cohen's kappa
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.984191074547715

# %%
#Predicting Wine Quality

# %%
# Isolate target labels
y_wine_quality = wines.quality

# %%
# Isolate data
X_wine_quality = wines.drop('quality', axis=1)

# %%
# Scale the data with `StandardScaler`
X_wine_quality =StandardScaler().fit_transform(X_wine_quality)

# %%
input_dim = X_wine_quality.shape[1]

# %%
from sklearn.model_selection import StratifiedKFold


seed = 7
np.random.seed(seed)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

for train, test in kfold.split(X_wine_quality,y_wine_quality):
    # Initialize the model
    model_wine_quality = Sequential()
    # Add input layer 
    model_wine_quality.add(Dense(64, input_dim=input_dim, activation='relu'))
    # Add Batchnormalization layer 
    model_wine_quality.add(BatchNormalization())
    # Add hidden layer
    model_wine_quality.add(Dense(32, activation = 'relu'))
    # Add Batchnormalization layer 
    model_wine_quality.add(BatchNormalization())
    # Add output layer 
    model_wine_quality.add(Dense(1))
    # Compile the model
    model_wine_quality.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    # Fit the model
    model_wine_quality.fit(X_wine_quality[train], y_wine_quality[train], epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 1s 6ms/step - loss: 24.6461 - mae: 4.8357
# Epoch 2/10
# 163/163 [==============================] - 1s 6ms/step - loss: 5.7720 - mae: 2.0815
# Epoch 3/10
# 163/163 [==============================] - 1s 4ms/step - loss: 0.7251 - mae: 0.6681
# Epoch 4/10
# 163/163 [==============================] - 0s 3ms/step - loss: 0.6409 - mae: 0.6283
# Epoch 5/10
# 163/163 [==============================] - 0s 3ms/step - loss: 0.5912 - mae: 0.6006
# Epoch 6/10
# 163/163 [==============================] - 0s 3ms/step - loss: 0.5505 - mae: 0.5787
# Epoch 7/10
# 163/163 [==============================] - 0s 3ms/step - loss: 0.5267 - mae: 0.5713
# Epoch 8/10
# 163/163 [==============================] - 0s 2ms/step - loss: 0.5136 - mae: 0.5599
# Epoch 9/10
# 163/163 [==============================] - 0s 2ms/step - loss: 0.5027 - mae: 0.5552
# Epoch 10/10
# 163/163 [==============================] - 0s 2ms/step - loss: 0.4977 - mae: 0.5532
# ...

# %%
y_wine_quality_pred = model_wine_quality.predict(X_wine_quality[test])

# %%
mse_value, mae_value = model_wine_quality.evaluate(X_wine_quality[test], y_wine_quality[test], verbose=0)

print('MSE: ' '{:.4f}'.format(mse_value)) 
print('MAE: ' '{:.4f}'.format(mae_value))
# Out:
# MSE: 0.4905
# MAE: 0.5443

# %%
from sklearn.metrics import r2_score

r2_score = r2_score(y_wine_quality[test], y_wine_quality_pred)
print('R2: ' '{:.4f}'.format(r2_score))
# Out:
# R2: 0.3576

# %%
h_callback_wine_quality = model_wine_quality.fit(X_wine_quality[train], y_wine_quality[train], epochs = 64,batch_size=32,
               validation_data=(X_wine_quality[test],  y_wine_quality[test]))
# Out:
# Epoch 1/64
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4935 - mae: 0.5477 - val_loss: 0.5043 - val_mae: 0.5481
# Epoch 2/64
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4733 - mae: 0.5408 - val_loss: 0.4986 - val_mae: 0.5474
# Epoch 3/64
# 163/163 [==============================] - 1s 6ms/step - loss: 0.4734 - mae: 0.5393 - val_loss: 0.5160 - val_mae: 0.5565
# Epoch 4/64
# 163/163 [==============================] - 1s 6ms/step - loss: 0.4674 - mae: 0.5362 - val_loss: 0.5224 - val_mae: 0.5617
# Epoch 5/64
# 163/163 [==============================] - 1s 5ms/step - loss: 0.4668 - mae: 0.5289 - val_loss: 0.4955 - val_mae: 0.5453
# Epoch 6/64
# 163/163 [==============================] - 1s 4ms/step - loss: 0.4577 - mae: 0.5297 - val_loss: 0.5326 - val_mae: 0.5690
# Epoch 7/64
# 163/163 [==============================] - 1s 3ms/step - loss: 0.4556 - mae: 0.5249 - val_loss: 0.5116 - val_mae: 0.5581
# Epoch 8/64
# ...

# %%
# summarize history for accuracy
plt.plot(h_callback_wine_quality.history['mae'])
plt.plot(h_callback_wine_quality.history['val_mae'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(h_callback_wine_quality.history['loss'])
plt.plot(h_callback_wine_quality.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def make_keras_model2(learning_rate=0.01,activation='relu',layer1_units=64, layer2_units=64,
                      layer3_units=64,dropout_rate=0.1, nbr_features=input_dim ,l2_regularization=0):
     
        # Describing optimization function
        opt = Adam(lr =learning_rate)  
        # Initialize the model
        model_02 = Sequential()
        # Add input layer 
        model_02.add(Dense(layer1_units,input_shape=(nbr_features,),activation=activation))
        # Add Batchnormalization layer
        model_02.add(BatchNormalization())
        # Add first hidden layer
        model_02.add(Dense(layer2_units, activation = activation,kernel_regularizer=l2(l2_regularization)))
        # Add Batchnormalization layer
        model_02.add(BatchNormalization())
        # Add droupout layer
        model_02.add(Dropout(rate=dropout_rate))
        # Add Batchnormalization layer
        model_02.add(BatchNormalization())
        # Add second hidden layer
        model_02.add(Dense(layer3_units, activation = activation,kernel_regularizer=l2(l2_regularization)))
        # Add Batchnormalization layer
        model_02.add(BatchNormalization())
        # Add output layer
        model_02.add(Dense(1,activation='linear'))
    
        # Compile your model with your optimizer, loss, and metrics
        model_02.compile(optimizer = opt, loss = 'mse', metrics = ['mae'])
        return model_02

# %%
from keras.wrappers.scikit_learn import KerasRegressor
regressor_keras = KerasRegressor(make_keras_model2, 
                                 batch_size=32, 
                                 layer1_units=64,
                                 layer2_units=64,
                                 layer3_units=64,
                                 dropout_rate=0,
                                 l2_regularization=0,
                                 epochs=10, 
                                 verbose=False)

# %%
pipeline_keras = Pipeline([('imputer', SimpleImputer()), 
                           ('scaler', StandardScaler()), 
                           ('model_02', regressor_keras)])

# %% [markdown]
# param_grid_keras_02 ={
#     'imputer__strategy': ['mean', 'median'],
#     'scaler': [MinMaxScaler(), StandardScaler()],
#     'model_02__layer1_units': [64,128],
#     'model_02__layer2_units': [32, 64],
#     'model_02__layer3_units': [16, 32],
#     'model_02__dropout_rate': [0, 0.2, 0.5],
#     'model_02__epochs': [10,20,30,40, 60],
#     'model_02__learning_rate':[0.01,0.1],
#     'model_02__activation':['relu','tanh'],
#     'model_02__batch_size':[32,64],
#
# }

# %%
   param_grid_keras_02 ={
    
    'scaler': [StandardScaler()],
    'model_02__layer1_units': [32,64],
    'model_02__layer2_units': [16, 32],
    'model_02__layer3_units': [8, 16],
    'model_02__dropout_rate': [0, 0.2],
    'model_02__epochs': [10,20,30],
    'model_02__learning_rate':[0.01,0.1],
    'model_02__activation':['relu','tanh'],
    'model_02__batch_size':[32,64],
    
}

# %%
gridsearch_keras_02 = GridSearchCV(pipeline_keras,
                                param_grid=param_grid_keras_02,
                                scoring='neg_mean_squared_error',
                                cv=2, 
                                refit=True,
                                verbose=True)

# %%
# Split the data up in train and test sets
X_wine_quality_train, X_wine_quality_test, y_wine_quality_train, y_wine_quality_test = train_test_split(X_wine_quality, y_wine_quality, test_size=0.33, random_state=42)

# %%
gridsearch_keras_02.fit(X_wine_quality_train, y_wine_quality_train)
# Out:
# Fitting 2 folds for each of 384 candidates, totalling 768 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 768 out of 768 | elapsed: 114.9min finished
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('imputer', SimpleImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('model_02',
#                                         <tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x00000026D971B648>)]),
#              param_grid={'model_02__activation': ['relu', 'tanh'],
#                          'model_02__batch_size': [32, 64],
#                          'model_02__dropout_rate': [0, 0.2],
#                          'model_02__epochs': [10, 20, 30],
#                          'model_02__layer1_units': [32, 64],
#                          'model_02__layer2_units': [16, 32],
# ...

# %%
y_pred_keras_02 = gridsearch_keras_02.predict(X_wine_quality_test)

# %%
print(f'Best params: {gridsearch_keras_02.best_params_}')
# Out:
# Best params: {'model_02__activation': 'relu', 'model_02__batch_size': 64, 'model_02__dropout_rate': 0.2, 'model_02__epochs': 20, 'model_02__layer1_units': 32, 'model_02__layer2_units': 16, 'model_02__layer3_units': 8, 'model_02__learning_rate': 0.01, 'scaler': StandardScaler()}

# %%
print(f'Best score: {gridsearch_keras_02.best_score_}')
# Out:
# Best score: -0.5010657509556093

# %%
print(f'Test MSE: {mean_squared_error(y_true=y_wine_quality_test, y_pred=y_pred_keras_02)}')
# Out:
# Test MSE: 0.49770170672850017

# %%
print(f'Test MAE: {mean_absolute_error(y_true=y_wine_quality_test, y_pred=y_pred_keras_02)}')
# Out:
# Test MAE: 0.5537773985962767

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_wine_quality_test, y_pred_keras_02)
print('R2: ' '{:.4f}'.format(r2_score))
# Out:
# R2: 0.3268

# %%
gridsearch_keras_02.best_params_['model_02__batch_size']
# Out:
# 64

# %%
input_dim
# Out:
# 12

# %%
# Describing optimization function
opt = Adam(lr = gridsearch_keras_02.best_params_['model_02__learning_rate'])  
# Initialize the model
model_02_tuned = Sequential()
# Add input layer 
model_02_tuned.add(Dense(gridsearch_keras_02.best_params_['model_02__layer1_units'],input_shape=(input_dim,),activation=gridsearch_keras_02.best_params_['model_02__activation']))
# Add Batchnormalization layer
model_02_tuned.add(BatchNormalization())
# Add first hidden layer
model_02_tuned.add(Dense(gridsearch_keras_02.best_params_['model_02__layer2_units'],activation = gridsearch_keras_02.best_params_['model_02__activation'],kernel_regularizer=l2(0)))
# Add Batchnormalization layer
model_02_tuned.add(BatchNormalization())
# Add droupout layer
model_02_tuned.add(Dropout(rate=gridsearch_keras_02.best_params_['model_02__dropout_rate']))
# Add Batchnormalization layer
model_02_tuned.add(BatchNormalization())
# Add second hidden layer
model_02_tuned.add(Dense(gridsearch_keras_02.best_params_['model_02__layer3_units'], activation = gridsearch_keras_02.best_params_['model_02__activation'],kernel_regularizer=l2(0)))
# Add Batchnormalization layer
model_02_tuned.add(BatchNormalization())
# Add output layer
model_02_tuned.add(Dense(1,activation='linear'))
    
# Compile your model with your optimizer, loss, and metrics
model_02_tuned.compile(optimizer = opt, loss = 'mse', metrics = ['mae'])

# %%
model_02_tuned_hist = model_02_tuned.fit(X_wine_quality_train, y_wine_quality_train,epochs = gridsearch_keras_02.best_params_['model_02__epochs']
                                                 ,batch_size=gridsearch_keras_02.best_params_['model_02__batch_size'],
               validation_data=(X_wine_quality_test, y_wine_quality_test))
# Out:
# Epoch 1/20
# 68/68 [==============================] - 1s 21ms/step - loss: 15.8312 - mae: 3.4937 - val_loss: 0.5689 - val_mae: 0.5920
# Epoch 2/20
# 68/68 [==============================] - 1s 7ms/step - loss: 0.6180 - mae: 0.6144 - val_loss: 0.5066 - val_mae: 0.5684
# Epoch 3/20
# 68/68 [==============================] - 0s 7ms/step - loss: 0.5535 - mae: 0.5793 - val_loss: 0.5115 - val_mae: 0.5667
# Epoch 4/20
# 68/68 [==============================] - 1s 8ms/step - loss: 0.5469 - mae: 0.5750 - val_loss: 0.4888 - val_mae: 0.5477
# Epoch 5/20
# 68/68 [==============================] - 0s 7ms/step - loss: 0.5220 - mae: 0.5635 - val_loss: 0.5365 - val_mae: 0.5775
# Epoch 6/20
# 68/68 [==============================] - 1s 7ms/step - loss: 0.5341 - mae: 0.5661 - val_loss: 0.4933 - val_mae: 0.5497
# Epoch 7/20
# 68/68 [==============================] - 0s 7ms/step - loss: 0.5215 - mae: 0.5587 - val_loss: 0.4817 - val_mae: 0.5442
# Epoch 8/20
# ...

# %%
# summarize history for accuracy
plt.plot(model_02_tuned_hist.history['mae'])
plt.plot(model_02_tuned_hist.history['val_mae'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model_02_tuned_hist.history['loss'])
plt.plot(model_02_tuned_hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
